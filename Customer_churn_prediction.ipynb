# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %% [markdown]
# # Import training and testing datasets

# %%
churn_20 = pd.read_csv(r"C:\Users\kdmq3\OneDrive\Documents\DA Entrance Tests\MCI\ChurnRate\churn-bigml-20.csv")
churn_80 = pd.read_csv(r"C:\Users\kdmq3\OneDrive\Documents\DA Entrance Tests\MCI\ChurnRate\churn-bigml-80.csv")

# %%
churn_20.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# ...

# %%
churn_20['Churn'].value_counts()
# Out:
# Churn
# False    572
# True      95
# Name: count, dtype: int64

# %%
churn_80.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
churn_80['Churn'].value_counts()
# Out:
# Churn
# False    2278
# True      388
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
churn_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   667 non-null    object
#  1   Account length          667 non-null    int64
#  2   Area code               667 non-null    int64
#  3   International plan      667 non-null    object
#  4   Voice mail plan         667 non-null    object
#  5   Number vmail messages   667 non-null    int64
#  6   Total day minutes       667 non-null    float64
#  7   Total day calls         667 non-null    int64
#  8   Total day charge        667 non-null    float64
#  9   Total eve minutes       667 non-null    float64
#  10  Total eve calls         667 non-null    int64
#  11  Total eve charge        667 non-null    float64
#  12  Total night minutes     667 non-null    float64
#  13  Total night calls       667 non-null    int64
# ...

# %%
churn_20.describe()
# Out:
#        Account length   Area code  Number vmail messages  Total day minutes  \
# count      667.000000  667.000000             667.000000         667.000000
# mean       102.841079  436.157421               8.407796         180.948126
# std         40.819480   41.783305              13.994480          55.508628
# min          1.000000  408.000000               0.000000          25.900000
# 25%         76.000000  408.000000               0.000000         146.250000
# 50%        102.000000  415.000000               0.000000         178.300000
# 75%        128.000000  415.000000              20.000000         220.700000
# max        232.000000  510.000000              51.000000         334.300000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count       667.000000        667.000000         667.000000       667.000000
# mean        100.937031         30.761769         203.355322       100.476762
# ...

# %%
churn_80.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2666 entries, 0 to 2665
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   2666 non-null   object
#  1   Account length          2666 non-null   int64
#  2   Area code               2666 non-null   int64
#  3   International plan      2666 non-null   object
#  4   Voice mail plan         2666 non-null   object
#  5   Number vmail messages   2666 non-null   int64
#  6   Total day minutes       2666 non-null   float64
#  7   Total day calls         2666 non-null   int64
#  8   Total day charge        2666 non-null   float64
#  9   Total eve minutes       2666 non-null   float64
#  10  Total eve calls         2666 non-null   int64
#  11  Total eve charge        2666 non-null   float64
#  12  Total night minutes     2666 non-null   float64
#  13  Total night calls       2666 non-null   int64
# ...

# %%
churn_80.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2666.000000  2666.000000            2666.000000         2666.00000
# mean       100.620405   437.438860               8.021755          179.48162
# std         39.563974    42.521018              13.612277           54.21035
# min          1.000000   408.000000               0.000000            0.00000
# 25%         73.000000   408.000000               0.000000          143.40000
# 50%        100.000000   415.000000               0.000000          179.95000
# 75%        127.000000   510.000000              19.000000          215.90000
# max        243.000000   510.000000              50.000000          350.80000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2666.000000       2666.000000        2666.000000      2666.000000
# mean        100.310203         30.512404         200.386159       100.023631
# ...

# %%
churn_20.hist(bins=50, figsize=(20,15), grid=False)
plt.tight_layout()
plt.show()

# %%
churn_80.hist(bins=50, figsize=(20,15), grid=False, color='red')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Machine Learning: Random Forest

# %% [markdown]
# ### Data Preperation for Machine Learning

# %% [markdown]
# Get dummies variables for categorical columns in the dataset used for training: 'State', 'International plan', 'Voice mail plan'

# %%
churn_20_copy = churn_20.copy()
categorical_cols = ['State', 'International plan', 'Voice mail plan']
churn_20_prepped = pd.get_dummies(churn_20_copy, columns=categorical_cols)
churn_20_prepped.head()
# Out:
#    Account length  Area code  Number vmail messages  Total day minutes  \
# 0             117        408                      0              184.5
# 1              65        415                      0              129.1
# 2             161        415                      0              332.9
# 3             111        415                      0              110.4
# 4              49        510                      0              119.3
#
#    Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# 0               97             31.37              351.6               80
# 1              137             21.95              228.5               83
# 2               67             56.59              317.8               97
# 3              103             18.77              137.3              102
# 4              117             20.28              215.1              109
#
#    Total eve charge  Total night minutes  ...  State_VA  State_VT  State_WA  \
# ...

# %% [markdown]
# Get dummies variables for categorical columns in the dataset used for testing: 'State', 'International plan', 'Voice mail plan'

# %%
churn_80_copy = churn_80.copy()
categorical_cols = ['State', 'International plan', 'Voice mail plan']
churn_80_prepped = pd.get_dummies(churn_80_copy, columns=categorical_cols)
churn_80_prepped.head()
# Out:
#    Account length  Area code  Number vmail messages  Total day minutes  \
# 0             128        415                     25              265.1
# 1             107        415                     26              161.6
# 2             137        415                      0              243.4
# 3              84        408                      0              299.4
# 4              75        415                      0              166.7
#
#    Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# 0              110             45.07              197.4               99
# 1              123             27.47              195.5              103
# 2              114             41.38              121.2              110
# 3               71             50.90               61.9               88
# 4              113             28.34              148.3              122
#
#    Total eve charge  Total night minutes  ...  State_VA  State_VT  State_WA  \
# ...

# %% [markdown]
# ### Training the model

# %% [markdown]
# Create variables for training and testing based on given dataset to predict Churn rate

# %%
x_train = churn_80_prepped.drop('Churn', axis=1)
y_train = churn_80_prepped['Churn']

# %%
x_test = churn_20_prepped.drop('Churn', axis=1)
y_test = churn_20_prepped['Churn']

# %% [markdown]
# Use RandomForestClassifier model to train data

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# Get the prediction from the model

# %%
prediction = model.predict(x_test)

# %% [markdown]
# ### Evaluate model performance

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.95      0.99      0.97       572
#         True       0.95      0.65      0.78        95
#
#     accuracy                           0.95       667
#    macro avg       0.95      0.82      0.87       667
# weighted avg       0.95      0.95      0.94       667

# %% [markdown]
# Overall, the model performance was decent. The f1-score indicates that the model provided accurate predictions for 97% of the customers who didn't churned and 78% of the customers who did churn.
